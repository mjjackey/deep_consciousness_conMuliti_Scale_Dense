# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 130811 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.3-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.3-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.3-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# ...

# %%
# import os
# os.chdir("/content/drive")

# %%
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# import os
# os.chdir("drive/My Drive/MSDNet")
# !cd /
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# chdir: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory

# %%
# !ls
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# all_shared_gcn_cifar100_b3_k5_s1.tar  ipynb    __pycache__     tools.py
# all_shared_gcn_cifar10_b2_k5_s1.tar   main.py  README.md       utils.py
# anytime_cifar10			      models   run_bash.ipynb
# anytime_cifar_10.pth.tar	      opts.py  run_me
# drive				      output   script.sh

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse -o nonempty drive  # mount the drive

# %%
# !ls
# Out:
# adc.json  drive  sample_data

# %%
import os
os.chdir("drive/MSDNet")

# %%
# !ls
# Out:
# all_shared_gcn_cifar100_b3_k5_s1.tar  ipynb    __pycache__     tools.py
# all_shared_gcn_cifar10_b2_k5_s1.tar   main.py  README.md       utils.py
# anytime_cifar_10.pth.tar	      models   run_bash.ipynb
# cifar10_acc.txt			      opts.py  run_me
# drive				      output   script.sh

# %%
# from importlib import reload  # Py3 only; unneeded in py2.
# foo = reload(foo)  # replace foo with your module's name

# %%
# This will clear the cache and refresh the files. Every time you change a file in drive folder, 
# you should call this command and the mounted drive would refresh with the changes.
# !google-drive-ocamlfuse -cc
# Out:
# Clearing cache...done

# %%
# Evaluating Cifar10 results --msd-base 2 --msd-step 1 --msd-stepmode even
# !python main.py --model msdnet -b 64 -j 2 cifar10 --msd-blocks 10 --msd-base 2 --msd-step 1 --msd-stepmode even --growth 6-12-24 --gpu 0 --msd-gcn --msd-gcn-kernel 5 --msd-share-weights --msd-all-gcn --debug --resume --evaluate-from all_shared_gcn_cifar10_b2_k5_s1.tar

# %%
# Evaluating Cifar10 results --msd-base 4 --msd-step 2 --msd-stepmode even 
# !python main.py --model msdnet -b 20  -j 2 cifar10 --msd-blocks 10 --msd-base 4 --msd-step 2 --msd-stepmode even --growth 6-12-24 --gpu 0 --debug --resume --evaluate-from anytime_cifar_10.pth.tar
# Out:
# | MSDNet-Block 10-2-cifar10
# Building network with the steps: [4, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# |-----------------Block 01----------------|
# |         First layer without GCN         |
# | Layer 01 input scales 3 output scales 3 |
# | Layer 02 input scales 3 output scales 3 |
# | Layer 03 input scales 3 output scales 3 |
# | Layer 04 input scales 3 output scales 3 |
# |-----------------Block 02----------------|
# | Layer 05 input scales 3 output scales 3 |
# | Layer 06 input scales 3 output scales 3 |
# |-----------------Block 03----------------|
# | Layer 07 input scales 3 output scales 3 |
# | Layer 08 input scales 3 output scales 3 |
# |-----------------Block 04----------------|
# | Layer 09 input scales 3 output scales 2 |
# |      Transition layer 1 was added!      |
# | Layer 10 input scales 2 output scales 2 |
# |-----------------Block 05----------------|
# | Layer 11 input scales 2 output scales 2 |
# | Layer 12 input scales 2 output scales 2 |
# ...

# %%
# Anytime train, cifar10
# !python main.py --model msdnet -b 32  -j 2 cifar10 --msd-blocks 10 --msd-base 4 --msd-step 2 --msd-stepmode even --growth 6-12-24 --gpu 0 --savedir anytime_cifar10/
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Anytime train, cifar100
# !python main.py --model msdnet -b 64  -j 2 cifar100 --msd-blocks 10 --msd-base 4 --msd-step 2 --msd-stepmode even --growth 6-12-24 --gpu 0  --savedir anytime_cifar100/
# Out:
# | MSDNet-Block 10-2-cifar100
# Building network with the steps: [4, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# |-----------------Block 01----------------|
# |         First layer without GCN         |
# | Layer 01 input scales 3 output scales 3 |
# | Layer 02 input scales 3 output scales 3 |
# | Layer 03 input scales 3 output scales 3 |
# | Layer 04 input scales 3 output scales 3 |
# |-----------------Block 02----------------|
# | Layer 05 input scales 3 output scales 3 |
# | Layer 06 input scales 3 output scales 3 |
# |-----------------Block 03----------------|
# | Layer 07 input scales 3 output scales 3 |
# | Layer 08 input scales 3 output scales 3 |
# |-----------------Block 04----------------|
# | Layer 09 input scales 3 output scales 2 |
# |      Transition layer 1 was added!      |
# | Layer 10 input scales 2 output scales 2 |
# |-----------------Block 05----------------|
# | Layer 11 input scales 2 output scales 2 |
# | Layer 12 input scales 2 output scales 2 |
# ...
